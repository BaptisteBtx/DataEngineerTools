# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                 object
# launched             object
# pledged              object
# state                object
# backers              object
# country              object
# usd pledged          object
# usd_pledged_real    float64
# dtype: object

# %%
df_ks['goal'] = pd.to_numeric(df_ks['goal'], errors='coerce')
df_ks['pledged'] = pd.to_numeric(df_ks['pledged'], errors='coerce')
df_ks['backers'] = pd.to_numeric(df_ks['backers'], errors='coerce')
df_ks['usd pledged'] = pd.to_numeric(df_ks['usd pledged'], errors='coerce')

# %%
# df_ks.dropna(inplace = True, subset = ['goal', 'pledged', 'backers', 'usd pledged'])

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers             float64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# dtype: object

# %%
data_dict = df_ks.to_dict("records")

# %%
data_dict
# Out:
# [{'ID': 872782264,
#   'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-09-16',
#   'goal': 2000.0,
#   'launched': '2011-08-17 06:31:31',
#   'pledged': 1145.0,
#   'state': 'canceled',
#   'backers': 24.0,
#   'country': 'US',
#   'usd pledged': 1145.0,
#   'usd_pledged_real': 1145.0},
#  {'ID': 1326492673,
#   'name': 'Ohceola jewelry',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-08-22',
#   'goal': 18000.0,
#   'launched': '2012-07-23 20:46:48',
#   'pledged': 1851.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd pledged': 1851.0,
#   'usd_pledged_real': 1851.0},
#  {'ID': 1688410639,
#   'name': 'Sluff Off & Harald: Two latest EGGs are Classics "old & new"',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-19',
#   'goal': 2000.0,
#   'launched': '2016-07-01 21:55:54',
#   'pledged': 7534.0,
#   'state': 'successful',
#   'backers': 254.0,
#   'country': 'US',
#   'usd pledged': 3796.0,
#   'usd_pledged_real': 7534.0},
#  {'ID': 156812982,
#   'name': 'SketchPlanner: Create and Plan- all in one beautiful book!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-09-27',
#   'goal': 13000.0,
#   'launched': '2017-08-28 15:47:02',
#   'pledged': 16298.0,
#   'state': 'successful',
#   'backers': 367.0,
#   'country': 'US',
#   'usd pledged': 2670.0,
#   'usd_pledged_real': 16298.0},
#  {'ID': 1835968190,
#   'name': 'Proven sales with custom motorcycle accessories',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-02-24',
#   'goal': 5000.0,
#   'launched': '2016-01-25 17:37:10',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd pledged': 0.70814759,
#   'usd_pledged_real': 0.7382253063635021},
#  {'ID': 1771789139,
#   'name': 'Room For Growth!',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-05-02',
#   'goal': 2000.0,
#   'launched': '2016-04-11 18:15:00',
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'ID': 1301627822,
#   'name': 'Build a mini Udemy with Laravel and Vuejs',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2018-01-11',
#   'goal': 3000.0,
#   'launched': '2017-12-12 01:37:26',
#   'pledged': 155.0,
#   'state': 'live',
#   'backers': 7.0,
#   'country': 'CA',
#   'usd pledged': 15.5639964,
#   'usd_pledged_real': 123.81180605479669},
#  {'ID': 881336601,
#   'name': 'Applitizer',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-08-20',
#   'goal': 100000.0,
#   'launched': '2017-07-21 16:50:05',
#   'pledged': 1000.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'HK',
#   'usd pledged': 128.08538,
#   'usd_pledged_real': 127.83146699391523},
#  {'ID': 1669374237,
#   'name': 'Help I Am Wolves fund their first album "ABCD" on 12" vinyl!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-12-04',
#   'goal': 1000.0,
#   'launched': '2017-10-27 16:55:47',
#   'pledged': 1465.0,
#   'state': 'successful',
#   'backers': 46.0,
#   'country': 'BE',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1720.2104175473205},
#  {'ID': 556821416,
#   'name': 'Eco  Bamboo Underwear funding....GOT WOOD ?',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2012-12-13',
#   'goal': 9500.0,
#   'launched': '2012-11-13 10:58:34',
#   'pledged': 1212.0,
#   'state': 'failed',
#   'backers': 43.0,
#   'country': 'GB',
#   'usd pledged': 1928.13711852,
#   'usd_pledged_real': 1953.6728081628705},
#  {'ID': 160394496,
#   'name': 'SHAKTI: The Power of Woman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-03-13',
#   'goal': 15000.0,
#   'launched': '2012-01-13 16:27:16',
#   'pledged': 18361.89,
#   'state': 'successful',
#   'backers': 126.0,
#   'country': 'US',
#   'usd pledged': 18361.89,
#   'usd_pledged_real': 18361.89},
#  {'ID': 1248488072,
#   'name': 'Coast to Coaster',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-06-21',
#   'goal': 25000.0,
#   'launched': '2017-05-07 06:05:42',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'ID': 895565490,
#   'name': 'Frostbite Gaming - Minecraft HUB',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-11-26',
#   'goal': 400.0,
#   'launched': '2014-10-17 11:25:49',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd pledged': 15.9921958,
#   'usd_pledged_real': 15.695876693192696},
#  {'ID': 1165822076,
#   'name': 'Support Ramsort album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'NOK',
#   'deadline': '2015-05-03',
#   'goal': 150000.0,
#   'launched': '2015-04-03 14:24:19',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'NO',
#   'usd pledged': 1.2455610000000001,
#   'usd_pledged_real': 1.3387776959635849},
#  {'ID': 424612381,
#   'name': 'Red No. 95 Issue 3',
#   'category': 'Comic Books',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2017-08-10',
#   'goal': 800.0,
#   'launched': '2017-07-11 08:16:21',
#   'pledged': 955.0,
#   'state': 'successful',
#   'backers': 34.0,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 955.0},
#  {'ID': 1182908609,
#   'name': 'Alice In Wonderland!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2012-06-15',
#   'goal': 220.0,
#   'launched': '2012-05-16 05:37:08',
#   'pledged': 320.0,
#   'state': 'successful',
#   'backers': 13.0,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'ID': 206040356,
#   'name': 'Un piano : 150 Pas',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'CAD',
#   'deadline': '2017-09-03',
#   'goal': 1500.0,
#   'launched': '2017-07-05 21:52:43',
#   'pledged': 1540.0,
#   'state': 'successful',
#   'backers': 31.0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1274.0961363448332},
#  {'ID': 396454289,
#   'name': 'Operation Penumbra: A WWII Supernatural Adventure, Vol. 1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2014-01-17',
#   'goal': 15000.0,
#   'launched': '2013-12-18 23:19:02',
#   'pledged': 5035.0,
#   'state': 'failed',
#   'backers': 81.0,
#   'country': 'US',
#   'usd pledged': 5035.0,
#   'usd_pledged_real': 5035.0},
#  {'ID': 1522195027,
#   'name': 'Emma Rae',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-27',
#   'goal': 12000.0,
#   'launched': '2017-06-27 18:00:25',
#   'pledged': 13415.0,
#   'state': 'successful',
#   'backers': 100.0,
#   'country': 'US',
#   'usd pledged': 1750.0,
#   'usd_pledged_real': 13415.0},
#  {'ID': 1429288669,
#   'name': 'Strange Occurrences: Performances for Non-Theater Spaces',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2010-09-22',
#   'goal': 3000.0,
#   'launched': '2010-07-23 23:30:10',
#   'pledged': 3080.98,
#   'state': 'successful',
#   'backers': 59.0,
#   'country': 'US',
#   'usd pledged': 3080.98,
#   'usd_pledged_real': 3080.98},
#  {'ID': 1441999253,
#   'name': 'Ancient Ruins II Base Series',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-06',
#   'goal': 1800.0,
#   'launched': '2014-10-22 14:58:46',
#   'pledged': 5630.95,
#   'state': 'successful',
#   'backers': 88.0,
#   'country': 'US',
#   'usd pledged': 5630.95,
#   'usd_pledged_real': 5630.95},
#  {'ID': 1202442815,
#   'name': 'The Craziest Thing Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-03-22',
#   'goal': 30000.0,
#   'launched': '2014-01-22 00:13:15',
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'ID': 2116917173,
#   'name': 'Look UP! To this nice shirt!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-11-10',
#   'goal': 3700.0,
#   'launched': '2012-09-26 06:15:44',
#   'pledged': 203.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'ID': 2117684680,
#   'name': 'Ghost Nest: Giving the Power of Design Back to the Consumer (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2010-11-17',
#   'goal': 18729.0,
#   'launched': '2010-10-08 01:29:29',
#   'pledged': 1781.0,
#   'state': 'canceled',
#   'backers': 32.0,
#   'country': 'US',
#   'usd pledged': 1781.0,
#   'usd_pledged_real': 1781.0},
#  {'ID': 350628546,
#   'name': 'Elli (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-11-03',
#   'goal': 5000.0,
#   'launched': '2014-09-04 00:10:14',
#   'pledged': 121.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'ID': 35969505,
#   'name': 'States, Firms, & Households: the search for equilibrium (2)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-01-22',
#   'goal': 100.0,
#   'launched': '2015-12-23 07:35:24',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1849047042,
#   'name': "Central Florida Artisans' Guild: Community Growth",
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-05-12',
#   'goal': 2000.0,
#   'launched': '2015-04-22 18:59:35',
#   'pledged': 121.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'ID': 295864582,
#   'name': 'Frankenstein Soft Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-29',
#   'goal': 215.0,
#   'launched': '2017-09-22 22:25:58',
#   'pledged': 18.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 18.0},
#  {'ID': 496463082,
#   'name': 'qualMeter XT: Greater Experience on Cable/Charger Testing',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-06-05',
#   'goal': 5000.0,
#   'launched': '2017-05-06 15:13:17',
#   'pledged': 10655.0,
#   'state': 'successful',
#   'backers': 222.0,
#   'country': 'CA',
#   'usd pledged': 5300.34825892,
#   'usd_pledged_real': 7887.334369679473},
#  {'ID': 1390262683,
#   'name': 'Candy Coburn - "THE GOOD LIFE" New Soul Rockin\' Studio Album',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 15000.0,
#   'launched': '2016-05-10 12:43:24',
#   'pledged': 15530.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd pledged': 15530.0,
#   'usd_pledged_real': 15530.0},
#  {'ID': 1041882251,
#   'name': "Gentlemen's Bar",
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 4000.0,
#   'launched': '2016-06-16 20:31:11',
#   'pledged': 613.0,
#   'state': 'failed',
#   'backers': 25.0,
#   'country': 'US',
#   'usd pledged': 433.0,
#   'usd_pledged_real': 613.0},
#  {'ID': 1130940376,
#   'name': 'A Sickle Life',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-01',
#   'goal': 5000.0,
#   'launched': '2016-06-01 15:15:40',
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'ID': 186326896,
#   'name': 'NYC Type',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2012-10-30',
#   'goal': 10000.0,
#   'launched': '2012-10-11 00:28:31',
#   'pledged': 10106.0,
#   'state': 'successful',
#   'backers': 179.0,
#   'country': 'US',
#   'usd pledged': 10106.0,
#   'usd_pledged_real': 10106.0},
#  {'ID': 1025722498,
#   'name': 'PatentSlice.com-Automated Patent Drill-Down & Analysis Tool',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-23',
#   'goal': 5000.0,
#   'launched': '2017-02-21 21:37:27',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1493170888,
#   'name': 'The Birdsongs - New CD Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-04-28',
#   'goal': 5000.0,
#   'launched': '2011-03-18 02:50:18',
#   'pledged': 6357.0,
#   'state': 'successful',
#   'backers': 83.0,
#   'country': 'US',
#   'usd pledged': 6357.0,
#   'usd_pledged_real': 6357.0},
#  {'ID': 1007463174,
#   'name': 'Brazilian pop artist Kiko London Tour support',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 8000.0,
#   'launched': '2017-03-14 19:22:11',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'ID': 2143760539,
#   'name': 'Emissary - Tabletop RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-03-21',
#   'goal': 5000.0,
#   'launched': '2016-02-20 15:46:23',
#   'pledged': 9324.0,
#   'state': 'successful',
#   'backers': 334.0,
#   'country': 'GB',
#   'usd pledged': 13350.07578744,
#   'usd_pledged_real': 13174.888019103872},
#  {'ID': 2062002375,
#   'name': 'Desktop Museum of Card Art',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-04-11',
#   'goal': 1600.0,
#   'launched': '2014-03-12 22:33:56',
#   'pledged': 587.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd pledged': 587.0,
#   'usd_pledged_real': 587.0},
#  {'ID': 1183084584,
#   'name': 'Act for Change: Healing Minds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2014-08-13',
#   'goal': 16000.0,
#   'launched': '2014-07-14 22:47:13',
#   'pledged': 1638.0,
#   'state': 'failed',
#   'backers': 38.0,
#   'country': 'GB',
#   'usd pledged': 2804.4439605000002,
#   'usd_pledged_real': 2733.827358301622},
#  {'ID': 1977195934,
#   'name': 'Book: Outrageously (un)loved - The fight against selfhatred',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-03-30',
#   'goal': 900.0,
#   'launched': '2015-01-29 23:17:48',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'NL',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1035882318,
#   'name': 'Help match our 2nd NEA grant for Glory Denied',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': '2015-10-26 14:06:42',
#   'pledged': 2650.0,
#   'state': 'successful',
#   'backers': 29.0,
#   'country': 'US',
#   'usd pledged': 2650.0,
#   'usd_pledged_real': 2650.0},
#  {'ID': 1021441525,
#   'name': 'The Alchemy of Art Book',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-12-22',
#   'goal': 7770.0,
#   'launched': '2016-11-28 02:06:47',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 18.499334023975138},
#  {'ID': 1691723287,
#   'name': 'The Om Space',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-08',
#   'goal': 15000.0,
#   'launched': '2016-06-08 18:13:45',
#   'pledged': 1512.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd pledged': 1512.0,
#   'usd_pledged_real': 1512.0},
#  {'ID': 680665134,
#   'name': 'Open Source Gemini Simulator',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-17',
#   'goal': 1675.0,
#   'launched': '2017-07-18 19:37:33',
#   'pledged': 1685.0,
#   'state': 'successful',
#   'backers': 28.0,
#   'country': 'US',
#   'usd pledged': 135.0,
#   'usd_pledged_real': 1685.0},
#  {'ID': 1864901261,
#   'name': 'Tenabris Ides',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-14',
#   'goal': 1500.0,
#   'launched': '2015-02-14 03:53:39',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'ID': 519449839,
#   'name': 'Johnny P - Resurrected (Album)',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-07',
#   'goal': 750.0,
#   'launched': '2013-07-08 22:54:55',
#   'pledged': 26.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 26.0,
#   'usd_pledged_real': 26.0},
#  {'ID': 1875047349,
#   'name': 'Hope for our youth today',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 6700.0,
#   'launched': '2014-07-21 20:03:14',
#   'pledged': 13.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 13.0,
#   'usd_pledged_real': 13.0},
#  {'ID': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': '2014-10-15 06:34:48',
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293.0,
#   'country': 'US',
#   'usd pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'ID': 1263082934,
#   'name': 'STEAM for Students',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': '2014-08-15 04:46:08',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 764437823,
#   'name': 'Cold Waters, Warm Hearts: Portraits of Women Who Fly-Fish',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-06-28',
#   'goal': 10000.0,
#   'launched': '2016-05-19 02:48:20',
#   'pledged': 586.0,
#   'state': 'failed',
#   'backers': 15.0,
#   'country': 'US',
#   'usd pledged': 586.0,
#   'usd_pledged_real': 586.0},
#  {'ID': 1341393677,
#   'name': 'Sure Set Hook',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-15',
#   'goal': 15000.0,
#   'launched': '2014-12-16 15:43:20',
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'ID': 1149469807,
#   'name': 'Bespoke by Demian Custom Menswear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 10000.0,
#   'launched': '2015-08-11 21:43:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1968352897,
#   'name': 'Renewable Soy + American Made Candles = LOVE',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2012-02-23',
#   'goal': 1000.0,
#   'launched': '2012-01-24 02:19:34',
#   'pledged': 2325.0,
#   'state': 'successful',
#   'backers': 39.0,
#   'country': 'US',
#   'usd pledged': 2325.0,
#   'usd_pledged_real': 2325.0},
#  {'ID': 693501911,
#   'name': 'Spray Art on canvas series',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'GBP',
#   'deadline': '2015-05-14',
#   'goal': 5000.0,
#   'launched': '2015-04-14 13:33:36',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 397524601,
#   'name': "Make Rubulad's Dream Home Come True",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-12-09',
#   'goal': 35000.0,
#   'launched': '2011-11-11 18:49:35',
#   'pledged': 37248.52,
#   'state': 'successful',
#   'backers': 733.0,
#   'country': 'US',
#   'usd pledged': 37248.52,
#   'usd_pledged_real': 37248.52},
#  {'ID': 520797301,
#   'name': 'Bad Habit Beers',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-10-17',
#   'goal': 25000.0,
#   'launched': '2015-09-17 21:35:33',
#   'pledged': 7522.0,
#   'state': 'failed',
#   'backers': 76.0,
#   'country': 'US',
#   'usd pledged': 7522.0,
#   'usd_pledged_real': 7522.0},
#  {'ID': 1195741430,
#   'name': 'Bring the BBBC home for Christmas (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-20',
#   'goal': 55000.0,
#   'launched': '2014-09-25 17:04:11',
#   'pledged': 1395.0,
#   'state': 'canceled',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'ID': 2024072867,
#   'name': 'Black Lotus Empire-issue #1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-09-23',
#   'goal': 2500.0,
#   'launched': '2012-08-14 18:25:36',
#   'pledged': 3905.51,
#   'state': 'successful',
#   'backers': 195.0,
#   'country': 'US',
#   'usd pledged': 3905.51,
#   'usd_pledged_real': 3905.51},
#  {'ID': 223758456,
#   'name': 'Toasty the Magic Fireplace',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-10-20',
#   'goal': 10000.0,
#   'launched': '2017-09-20 18:04:19',
#   'pledged': 33.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 33.0},
#  {'ID': 1594750207,
#   'name': 'Lake Forest Drone',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2016-04-14',
#   'goal': 875.0,
#   'launched': '2016-03-05 18:11:17',
#   'pledged': 103.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 103.0,
#   'usd_pledged_real': 103.0},
#  {'ID': 726485587,
#   'name': 'The Meadow Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-20',
#   'goal': 20000.0,
#   'launched': '2012-01-07 17:39:58',
#   'pledged': 21635.0,
#   'state': 'successful',
#   'backers': 290.0,
#   'country': 'US',
#   'usd pledged': 21635.0,
#   'usd_pledged_real': 21635.0},
#  {'ID': 260647442,
#   'name': 'Clash in the Caucuses 2016',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-13',
#   'goal': 17500.0,
#   'launched': '2016-10-14 02:44:13',
#   'pledged': 682.0,
#   'state': 'failed',
#   'backers': 15.0,
#   'country': 'US',
#   'usd pledged': 86.0,
#   'usd_pledged_real': 682.0},
#  {'ID': 1043191090,
#   'name': 'Politics with Allies',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 20000.0,
#   'launched': '2017-03-21 18:05:36',
#   'pledged': 554.0,
#   'state': 'failed',
#   'backers': 23.0,
#   'country': 'US',
#   'usd pledged': 127.0,
#   'usd_pledged_real': 554.0},
#  {'ID': 395755489,
#   'name': 'Kawaii Heroes Soft Enamel Pins | Stickers | Commissions',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-12-03',
#   'goal': 800.0,
#   'launched': '2017-11-03 19:38:21',
#   'pledged': 23.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 23.0,
#   'usd_pledged_real': 23.0},
#  {'ID': 830800632,
#   'name': 'Martin Game Studios',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-01',
#   'goal': 5000.0,
#   'launched': '2014-10-02 18:10:05',
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'ID': 2113778157,
#   'name': 'Air Basketball',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 1500.0,
#   'launched': '2013-11-08 03:02:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 163783398,
#   'name': 'ZERUBA',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-02-24',
#   'goal': 1000.0,
#   'launched': '2015-01-25 02:21:51',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'ID': 2069080555,
#   'name': 'Crashpads and Paddles: A Rock climbing adventure by canoe',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'CAD',
#   'deadline': '2015-06-06',
#   'goal': 1500.0,
#   'launched': '2015-05-05 20:37:22',
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd pledged': 65.7148416,
#   'usd_pledged_real': 65.02479070145492},
#  {'ID': 1224888533,
#   'name': 'Eating Up Easter - Finishing Funds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-06-09',
#   'goal': 30000.0,
#   'launched': '2017-05-10 16:22:26',
#   'pledged': 35182.0,
#   'state': 'successful',
#   'backers': 249.0,
#   'country': 'US',
#   'usd pledged': 4215.0,
#   'usd_pledged_real': 35182.0},
#  {'ID': 1841566953,
#   'name': 'Clocks Cameras Computers & Murder:  What Else Can Go Wrong?',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-05-19',
#   'goal': 6000.0,
#   'launched': '2015-04-19 20:03:18',
#   'pledged': 900.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 900.0,
#   'usd_pledged_real': 900.0},
#  {'ID': 449615827,
#   'name': 'High Caliber Community (HC2); a place for veteran networking',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-19',
#   'goal': 75000.0,
#   'launched': '2017-11-19 21:37:19',
#   'pledged': 4196.0,
#   'state': 'failed',
#   'backers': 30.0,
#   'country': 'US',
#   'usd pledged': 1876.0,
#   'usd_pledged_real': 4196.0},
#  {'ID': 442102012,
#   'name': "Rudely Stamp'd Historical Impressions",
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-12-26',
#   'goal': 6000.0,
#   'launched': '2017-10-27 05:04:26',
#   'pledged': 550.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 550.0},
#  {'ID': 1054276073,
#   'name': '(Teacher) Documentary, Jack teaches Buddhist Monks English',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-09-01',
#   'goal': 2390.0,
#   'launched': '2016-07-28 16:34:56',
#   'pledged': 2773.0,
#   'state': 'successful',
#   'backers': 43.0,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 2773.0},
#  {'ID': 1292948737,
#   'name': 'Tarot eCards App: Tarot Reading App for mobile devices',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-01-13',
#   'goal': 12000.0,
#   'launched': '2013-12-09 13:51:59',
#   'pledged': 796.66,
#   'state': 'failed',
#   'backers': 29.0,
#   'country': 'US',
#   'usd pledged': 796.66,
#   'usd_pledged_real': 796.66},
#  {'ID': 2036356057,
#   'name': 'Sound is Revolution',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2017-05-23',
#   'goal': 50000.0,
#   'launched': '2017-04-23 22:07:56',
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 14.125019261389902},
#  {'ID': 56346579,
#   'name': 'City of the Shroud',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 14000.0,
#   'launched': '2016-04-06 18:00:04',
#   'pledged': 16239.0,
#   'state': 'successful',
#   'backers': 302.0,
#   'country': 'US',
#   'usd pledged': 16239.0,
#   'usd_pledged_real': 16239.0},
#  {'ID': 797794426,
#   'name': "Skunk Rider's first album",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-05-16',
#   'goal': 500.0,
#   'launched': '2015-05-01 17:31:59',
#   'pledged': 1395.0,
#   'state': 'successful',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'ID': 1086953170,
#   'name': "'Jamie and Friends' - Greeting Cards",
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'GBP',
#   'deadline': '2015-07-25',
#   'goal': 1000.0,
#   'launched': '2015-06-25 18:58:28',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd pledged': 31.478563800000003,
#   'usd_pledged_real': 31.15167751783433},
#  {'ID': 955493948,
#   'name': 'W.E.T West End Terminal: Outdoor Chair Show/Art Installation',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-06-20',
#   'goal': 8500.0,
#   'launched': '2011-05-04 02:51:56',
#   'pledged': 8644.0,
#   'state': 'successful',
#   'backers': 47.0,
#   'country': 'US',
#   'usd pledged': 8644.0,
#   'usd_pledged_real': 8644.0},
#  {'ID': 133917405,
#   'name': 'BrainScrambler',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-05-04',
#   'goal': 8000.0,
#   'launched': '2012-04-04 21:26:16',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1702541310,
#   'name': 'Paint Ring',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-06-24',
#   'goal': 55000.0,
#   'launched': '2017-05-15 19:52:07',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'ID': 87518909,
#   'name': 'Just Rock Showcase and Songwriter Circle 2014 at the studio',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-12-31',
#   'goal': 1500.0,
#   'launched': '2013-11-15 17:38:39',
#   'pledged': 2180.0,
#   'state': 'successful',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 2180.0,
#   'usd_pledged_real': 2180.0},
#  {'ID': 1957326840,
#   'name': 'BRIGADE RETURNS!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-06-15',
#   'goal': 17500.0,
#   'launched': '2013-05-16 21:24:04',
#   'pledged': 35343.0,
#   'state': 'successful',
#   'backers': 562.0,
#   'country': 'US',
#   'usd pledged': 35343.0,
#   'usd_pledged_real': 35343.0},
#  {'ID': 1593966557,
#   'name': 'Red Box Games Dwarves, and Goblins, and Orcs Oh MY!!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-16',
#   'goal': 5000.0,
#   'launched': '2013-05-19 21:49:38',
#   'pledged': 39258.0,
#   'state': 'successful',
#   'backers': 269.0,
#   'country': 'US',
#   'usd pledged': 39258.0,
#   'usd_pledged_real': 39258.0},
#  {'ID': 1029624752,
#   'name': 'Doodle Art to Color Returns!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-06-29',
#   'goal': 25.0,
#   'launched': '2014-06-14 18:50:10',
#   'pledged': 25.5,
#   'state': 'successful',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 25.5,
#   'usd_pledged_real': 25.5},
#  {'ID': 888065158,
#   'name': 'New Patent Design Pocket Sheet+',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-17',
#   'goal': 25000.0,
#   'launched': '2015-06-18 23:21:20',
#   'pledged': 190.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 190.0,
#   'usd_pledged_real': 190.0},
#  {'ID': 14239768,
#   'name': 'What I Did Today',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-17',
#   'goal': 5000.0,
#   'launched': '2012-08-16 00:00:27',
#   'pledged': 360.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd pledged': 360.0,
#   'usd_pledged_real': 360.0},
#  {'ID': 1890385189,
#   'name': 'The Falling Girl- Chronicles of the Closed World, Book 1',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-04-09',
#   'goal': 500.0,
#   'launched': '2012-03-10 01:37:26',
#   'pledged': 695.0,
#   'state': 'successful',
#   'backers': 9.0,
#   'country': 'US',
#   'usd pledged': 695.0,
#   'usd_pledged_real': 695.0},
#  {'ID': 368889340,
#   'name': '"Intermittent Polarity" Art book by Brent and Kayla Woodside',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-08-12',
#   'goal': 1000.0,
#   'launched': '2012-07-13 03:32:53',
#   'pledged': 610.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 610.0,
#   'usd_pledged_real': 610.0},
#  {'ID': 671724371,
#   'name': 'The Dark Lord and the Seamstress',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': '2014-08-11 21:02:05',
#   'pledged': 5336.0,
#   'state': 'successful',
#   'backers': 99.0,
#   'country': 'CA',
#   'usd pledged': 4862.92048512,
#   'usd_pledged_real': 4860.630351612315},
#  {'ID': 231038205,
#   'name': "Towering Trees' First Album!",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-11',
#   'goal': 2250.0,
#   'launched': '2013-07-12 21:23:16',
#   'pledged': 2267.0,
#   'state': 'successful',
#   'backers': 66.0,
#   'country': 'US',
#   'usd pledged': 2267.0,
#   'usd_pledged_real': 2267.0},
#  {'ID': 673468258,
#   'name': 'Daybook notebooks (Canceled)',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2016-02-25',
#   'goal': 1000.0,
#   'launched': '2016-01-26 06:29:43',
#   'pledged': 52.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 52.0,
#   'usd_pledged_real': 52.0},
#  {'ID': 765608919,
#   'name': 'Big Barbeque',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-04',
#   'goal': 20000.0,
#   'launched': '2014-09-04 15:25:21',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1451163055,
#   'name': 'iKlimt App: The Life & Work of Gustav Klimt',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-02-11',
#   'goal': 5000.0,
#   'launched': '2012-01-12 07:17:54',
#   'pledged': 66.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 66.0,
#   'usd_pledged_real': 66.0},
#  {'ID': 523925424,
#   'name': 'Seasons in the Sanctuary',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-10-02',
#   'goal': 4000.0,
#   'launched': '2012-09-07 21:56:47',
#   'pledged': 4808.0,
#   'state': 'successful',
#   'backers': 101.0,
#   'country': 'US',
#   'usd pledged': 4808.0,
#   'usd_pledged_real': 4808.0},
#  {'ID': 488491938,
#   'name': 'Charlie Chipmink',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-06-03',
#   'goal': 35000.0,
#   'launched': '2017-05-04 02:14:23',
#   'pledged': 430.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 430.0},
#  {'ID': 899938474,
#   'name': '500 Years Later: An Oral History of Final Fantasy VII',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'GBP',
#   'deadline': '2017-12-10',
#   'goal': 38000.0,
#   'launched': '2017-11-10 14:00:05',
#   'pledged': 72881.0,
#   'state': 'successful',
#   'backers': 1871.0,
#   'country': 'GB',
#   'usd pledged': 52551.44488998,
#   'usd_pledged_real': 97495.75267882225},
#  {'ID': 2146928537,
#   'name': 'Crimson Apple, Debut Album "Hello"',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-08-27',
#   'goal': 8000.0,
#   'launched': '2015-07-27 13:53:12',
#   'pledged': 8805.0,
#   'state': 'undefined',
#   'backers': 0.0,
#   'country': 'N,0"',
#   'usd pledged': nan,
#   'usd_pledged_real': 8805.0},
#  {'ID': 870077018,
#   'name': 'Take every shower with Matt Gator and stop shower mat mold',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-06-08',
#   'goal': 34000.0,
#   'launched': '2017-05-10 07:49:12',
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 21.0},
#  {'ID': 1564568013,
#   'name': 'The VDown Podcast Intro (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-03',
#   'goal': 1100.0,
#   'launched': '2014-09-03 01:45:25',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1010701682,
#   'name': 'XPLUS Watches: Second Release',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'AUD',
#   'deadline': '2015-10-29',
#   'goal': 10000.0,
#   'launched': '2015-09-30 00:56:12',
#   'pledged': 16889.0,
#   'state': 'successful',
#   'backers': 114.0,
#   'country': 'AU',
#   'usd pledged': 11874.69592693,
#   'usd_pledged_real': 11970.37352044794},
#  {'ID': 1425142887,
#   'name': 'Mathatar - An online Maths adventure game for KS2 to GCSE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-01-12',
#   'goal': 5000.0,
#   'launched': '2016-12-07 18:21:50',
#   'pledged': 369.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'GB',
#   'usd pledged': 154.21025895,
#   'usd_pledged_real': 449.34242571846085},
#  {'ID': 1843557102,
#   'name': 'Son of a Gun',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-26',
#   'goal': 20000.0,
#   'launched': '2011-12-28 17:57:05',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1721659818,
#   'name': 'Bourbon Chicken',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'CAD',
#   'deadline': '2014-08-05',
#   'goal': 30.0,
#   'launched': '2014-07-21 20:36:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 186346662,
#   'name': 'T-Shirt of the Year',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2011-07-03',
#   'goal': 1700.0,
#   'launched': '2011-04-04 06:35:03',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 619587010,
#   'name': 'Nobody: A Fallout Tale',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-11',
#   'goal': 8200.0,
#   'launched': '2015-11-10 22:37:04',
#   'pledged': 1229.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 1229.0,
#   'usd_pledged_real': 1229.0},
#  {'ID': 831196575,
#   'name': 'The Tower',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 50000.0,
#   'launched': '2015-06-22 17:51:49',
#   'pledged': 283.0,
#   'state': 'failed',
#   'backers': 23.0,
#   'country': 'GB',
#   'usd pledged': 449.38753223,
#   'usd_pledged_real': 439.1273314092417},
#  {'ID': 1517578386,
#   'name': 'AutoDock Car Organizer',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-16',
#   'goal': 50000.0,
#   'launched': '2017-09-01 15:31:27',
#   'pledged': 1775.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1775.0},
#  {'ID': 569529453,
#   'name': 'Let Me Tell You/No Money Down David Pemberton/Sally Phillips',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-09-30',
#   'goal': 10000.0,
#   'launched': '2015-08-31 23:19:47',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 639226845,
#   'name': 'Kiss Kiss Missiles',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-03-08',
#   'goal': 4000.0,
#   'launched': '2012-02-03 00:35:06',
#   'pledged': 4075.0,
#   'state': 'successful',
#   'backers': 76.0,
#   'country': 'US',
#   'usd pledged': 4075.0,
#   'usd_pledged_real': 4075.0},
#  {'ID': 2072974553,
#   'name': 'The Fountain of Light: a luminous juggling machine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-05-20',
#   'goal': 8000.0,
#   'launched': '2011-04-03 05:55:28',
#   'pledged': 8295.36,
#   'state': 'successful',
#   'backers': 124.0,
#   'country': 'US',
#   'usd pledged': 8295.36,
#   'usd_pledged_real': 8295.36},
#  {'ID': 328543359,
#   'name': 'Dead of Winter',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-12-10',
#   'goal': 700.0,
#   'launched': '2017-11-22 18:00:03',
#   'pledged': 767.0,
#   'state': 'successful',
#   'backers': 23.0,
#   'country': 'US',
#   'usd pledged': 226.0,
#   'usd_pledged_real': 767.0},
#  {'ID': 893780456,
#   'name': 'To Nowhere From Nobody: An Open Source Music Project',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-11-09',
#   'goal': 2500.0,
#   'launched': '2012-10-20 15:14:49',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'ID': 1771281327,
#   'name': 'Swiss Producer Battle (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'CHF',
#   'deadline': '2015-08-16',
#   'goal': 20000.0,
#   'launched': '2015-07-10 20:55:47',
#   'pledged': 175.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'CH',
#   'usd pledged': 185.09312849999998,
#   'usd_pledged_real': 183.3881751304676},
#  {'ID': 1840068470,
#   'name': 'Diamond by Stay high clothing',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2016-08-01',
#   'goal': 2000.0,
#   'launched': '2016-07-11 17:28:19',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'AU',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 933275417,
#   'name': 'Fruition of FORMS OF IDENTIFICATION',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-12-16',
#   'goal': 2000.0,
#   'launched': '2010-10-15 00:16:02',
#   'pledged': 2196.0,
#   'state': 'successful',
#   'backers': 44.0,
#   'country': 'US',
#   'usd pledged': 2196.0,
#   'usd_pledged_real': 2196.0},
#  {'ID': 1612333257,
#   'name': 'CUSTOM PET PORTRAIT IN 3 STYLES ( Cat / Dog / all animals! )',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'HKD',
#   'deadline': '2017-04-14',
#   'goal': 800.0,
#   'launched': '2017-03-15 03:59:16',
#   'pledged': 1250.0,
#   'state': 'successful',
#   'backers': 3.0,
#   'country': 'HK',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 160.74689437000075},
#  {'ID': 350352717,
#   'name': '"The \'Devil" (Canceled)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-10',
#   'goal': 600.0,
#   'launched': '2013-02-07 19:08:20',
#   'pledged': 320.0,
#   'state': 'canceled',
#   'backers': 11.0,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'ID': 358910116,
#   'name': 'Piano Wars: Dueling Piano Competition - TV Pilot Episode',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-06-21',
#   'goal': 12500.0,
#   'launched': '2011-04-22 03:01:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1509749942,
#   'name': 'Clash Calc (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-10',
#   'goal': 200.0,
#   'launched': '2015-07-20 19:05:57',
#   'pledged': 10.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'ID': 256728964,
#   'name': '"Film School Porno" My film school senior project',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-01',
#   'goal': 2000.0,
#   'launched': '2010-08-17 00:59:19',
#   'pledged': 2038.0,
#   'state': 'successful',
#   'backers': 12.0,
#   'country': 'US',
#   'usd pledged': 2038.0,
#   'usd_pledged_real': 2038.0},
#  {'ID': 640450615,
#   'name': 'Carry the Tune',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-13',
#   'goal': 6000.0,
#   'launched': '2014-03-14 04:43:39',
#   'pledged': 6756.0,
#   'state': 'successful',
#   'backers': 127.0,
#   'country': 'US',
#   'usd pledged': 6756.0,
#   'usd_pledged_real': 6756.0},
#  {'ID': 7168821,
#   'name': 'FitCraft',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 5000.0,
#   'launched': '2015-03-02 23:00:51',
#   'pledged': 1504.0,
#   'state': 'failed',
#   'backers': 71.0,
#   'country': 'US',
#   'usd pledged': 1504.0,
#   'usd_pledged_real': 1504.0},
#  {'ID': 727551984,
#   'name': 'Robert Rex Waller Jr "Fancy Free" Solo Covers LP (Pre-Order)',
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-04-23',
#   'goal': 7000.0,
#   'launched': '2016-03-22 18:46:14',
#   'pledged': 9244.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd pledged': 9244.0,
#   'usd_pledged_real': 9244.0},
#  {'ID': 757625439,
#   'name': 'SeaGulls',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-01',
#   'goal': 8000.0,
#   'launched': '2015-05-02 22:42:38',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 2012699952,
#   'name': 'iCROS - microscope for your smartphone, tablet or iPod touch',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CHF',
#   'deadline': '2016-11-20',
#   'goal': 20000.0,
#   'launched': '2016-10-18 06:20:52',
#   'pledged': 4293.0,
#   'state': 'failed',
#   'backers': 268.0,
#   'country': 'CH',
#   'usd pledged': 1501.75625937,
#   'usd_pledged_real': 4235.398579321231},
#  {'ID': 1185745802,
#   'name': 'The Microbrew Project',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-26',
#   'goal': 15000.0,
#   'launched': '2014-08-27 18:40:21',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1770997012,
#   'name': 'So you want to be an entreprenuer',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-28',
#   'goal': 1000.0,
#   'launched': '2014-10-29 16:23:54',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1457582752,
#   'name': 'Zoigl Beer - The New Sheriff in Town (Canceled)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-14',
#   'goal': 15000.0,
#   'launched': '2015-11-13 05:52:51',
#   'pledged': 3681.0,
#   'state': 'canceled',
#   'backers': 28.0,
#   'country': 'US',
#   'usd pledged': 3681.0,
#   'usd_pledged_real': 3681.0},
#  {'ID': 1446627191,
#   'name': 'The Eastern Addition',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-10-16',
#   'goal': 10000.0,
#   'launched': '2012-09-17 05:44:11',
#   'pledged': 11204.0,
#   'state': 'successful',
#   'backers': 195.0,
#   'country': 'US',
#   'usd pledged': 11204.0,
#   'usd_pledged_real': 11204.0},
#  {'ID': 555087193,
#   'name': 'Christian Short Video and Devotional Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-29',
#   'goal': 500.0,
#   'launched': '2012-08-30 04:06:37',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'ID': 2012910935,
# ...
#   'country': 'CA',
#   'usd pledged': 8962.6888704,
#   'usd_pledged_real': 9057.195289799663},
#  {'ID': 1382219843,
#   'name': 'Zipper',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2014-08-18',
#   'goal': 10000.0,
#   'launched': '2014-07-29 01:03:31',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'CA',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1361712743,
#   'name': "A set of 4 bumper stickers to save America's infrastructure",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-24',
#   'goal': 140.0,
#   'launched': '2016-01-25 20:50:47',
#   'pledged': 96.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 96.0,
#   'usd_pledged_real': 96.0},
#  {'ID': 478602668,
#   'name': 'NoHo Fringe Festival performance - #Right2Recess',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-12-03',
#   'goal': 3000.0,
#   'launched': '2017-11-03 20:51:42',
#   'pledged': 540.0,
#   'state': 'failed',
#   'backers': 10.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 540.0},
#  {'ID': 189295089,
#   'name': 'A MAN NAMED MAGICK: A Short Documentary About A Professional Magician',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-27',
#   'goal': 5000.0,
#   'launched': '2010-09-27 20:51:47',
#   'pledged': 5161.0,
#   'state': 'successful',
#   'backers': 79.0,
#   'country': 'US',
#   'usd pledged': 5161.0,
#   'usd_pledged_real': 5161.0},
#  {'ID': 887319573,
#   'name': 'PhiLOCK (Canceled)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-12-07',
#   'goal': 100000.0,
#   'launched': '2015-10-28 13:56:59',
#   'pledged': 2532.0,
#   'state': 'canceled',
#   'backers': 34.0,
#   'country': 'US',
#   'usd pledged': 2532.0,
#   'usd_pledged_real': 2532.0},
#  {'ID': 827535157,
#   'name': 'Cravar ï¿½ Leather Tote Bags (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-22',
#   'goal': 15000.0,
#   'launched': '2015-10-23 16:33:13',
#   'pledged': 6748.0,
#   'state': 'canceled',
#   'backers': 35.0,
#   'country': 'US',
#   'usd pledged': 6748.0,
#   'usd_pledged_real': 6748.0},
#  {'ID': 1169744690,
#   'name': 'Camper Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-26',
#   'goal': 350.0,
#   'launched': '2017-09-11 17:57:41',
#   'pledged': 379.0,
#   'state': 'successful',
#   'backers': 21.0,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 379.0},
#  {'ID': 634066630,
#   'name': "Plug 'N Plunge (Bathtub Overflow Pipe Plug)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-01',
#   'goal': 2500.0,
#   'launched': '2015-02-02 21:15:46',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 575660043,
#   'name': 'CANCELED (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-09-12',
#   'goal': 33000.0,
#   'launched': '2014-08-10 19:42:03',
#   'pledged': 3649.0,
#   'state': 'canceled',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 3649.0,
#   'usd_pledged_real': 3649.0},
#  {'ID': 2067634614,
#   'name': 'Changing the Radio / Production Industry with an iOS Device',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'GBP',
#   'deadline': '2012-12-21',
#   'goal': 500.0,
#   'launched': '2012-11-21 01:18:53',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1707385269,
#   'name': 'Better Food Control - Less Food Poisoning',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'NOK',
#   'deadline': '2017-04-18',
#   'goal': 200000.0,
#   'launched': '2017-02-17 23:25:04',
#   'pledged': 705.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'NO',
#   'usd pledged': 84.043491,
#   'usd_pledged_real': 81.55568923233541},
#  {'ID': 1613602272,
#   'name': 'ROPIX JUMP ROPE SHOES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-03-30',
#   'goal': 10000.0,
#   'launched': '2014-02-05 05:36:38',
#   'pledged': 10690.0,
#   'state': 'successful',
#   'backers': 117.0,
#   'country': 'US',
#   'usd pledged': 10690.0,
#   'usd_pledged_real': 10690.0},
#  {'ID': 1109297992,
#   'name': 'Symphony of 1000: Be a part of it!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-01-23',
#   'goal': 4000.0,
#   'launched': '2013-12-24 21:40:33',
#   'pledged': 162.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'ID': 142828580,
#   'name': 'THE POWER PRINCIPLE',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-08-24',
#   'goal': 7000.0,
#   'launched': '2012-07-10 12:37:25',
#   'pledged': 7263.0,
#   'state': 'successful',
#   'backers': 189.0,
#   'country': 'US',
#   'usd pledged': 7263.0,
#   'usd_pledged_real': 7263.0},
#  {'ID': 1109543634,
#   'name': "'AlwaysOn' 5pee (for scale)",
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'GBP',
#   'deadline': '2014-11-05',
#   'goal': 200.0,
#   'launched': '2014-09-06 01:24:05',
#   'pledged': 4.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'GB',
#   'usd pledged': 6.58338684,
#   'usd_pledged_real': 6.327812317086678},
#  {'ID': 1434110341,
#   'name': 'The Prettiest Panties in the World (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-01-11',
#   'goal': 30000.0,
#   'launched': '2015-12-01 18:00:24',
#   'pledged': 427.0,
#   'state': 'canceled',
#   'backers': 9.0,
#   'country': 'US',
#   'usd pledged': 427.0,
#   'usd_pledged_real': 427.0},
#  {'ID': 48806525,
#   'name': 'Coffee Crisis for the Sega Genesis - Metal, Aliens & Awesome',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-04',
#   'goal': 10000.0,
#   'launched': '2016-11-04 21:22:22',
#   'pledged': 15076.0,
#   'state': 'successful',
#   'backers': 213.0,
#   'country': 'US',
#   'usd pledged': 1917.0,
#   'usd_pledged_real': 15076.0},
#  {'ID': 1439048120,
#   'name': 'The Black Operator',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-07-12',
#   'goal': 3300.0,
#   'launched': '2013-06-12 03:05:30',
#   'pledged': 1134.0,
#   'state': 'failed',
#   'backers': 32.0,
#   'country': 'US',
#   'usd pledged': 1134.0,
#   'usd_pledged_real': 1134.0},
#  {'ID': 1300265365,
#   'name': 'The Athlete Spot: We Have The Ingredients For Your Success',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2018-01-09',
#   'goal': 50000.0,
#   'launched': '2017-11-10 03:59:11',
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 513123115,
#   'name': "Kaila Gieser's debut EP!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-05-10',
#   'goal': 1500.0,
#   'launched': '2013-04-08 19:15:48',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 1506474844,
#   'name': "The Revolution's Bride",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 15000.0,
#   'launched': '2016-06-04 19:59:25',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'ID': 1252795414,
#   'name': 'EZC Smartlight "The Smarter Way To Ride"',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2016-04-12',
#   'goal': 400.0,
#   'launched': '2016-03-08 13:26:58',
#   'pledged': 1595.0,
#   'state': 'successful',
#   'backers': 22.0,
#   'country': 'CA',
#   'usd pledged': 1195.5930195,
#   'usd_pledged_real': 1238.2578992314259},
#  {'ID': 1721170633,
#   'name': 'LINJA shoes - The Finest Comfortable High Heels',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-09-22',
#   'goal': 25000.0,
#   'launched': '2016-09-06 12:32:38',
#   'pledged': 19410.0,
#   'state': 'failed',
#   'backers': 112.0,
#   'country': 'NL',
#   'usd pledged': 4733.727817600001,
#   'usd_pledged_real': 21766.434162424022},
#  {'ID': 666068495,
#   'name': '360ï¿½ India',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 700.0,
#   'launched': '2015-07-22 11:40:00',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd pledged': 24.9036152,
#   'usd_pledged_real': 24.826986934798125},
#  {'ID': 1884096172,
#   'name': 'The Wing Commander Orchestral Project Volume 2, Phase 1!',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-08-26',
#   'goal': 15000.0,
#   'launched': '2017-07-27 21:58:33',
#   'pledged': 16552.0,
#   'state': 'successful',
#   'backers': 275.0,
#   'country': 'US',
#   'usd pledged': 5130.0,
#   'usd_pledged_real': 16552.0},
#  {'ID': 358516752,
#   'name': 'My YouTube Band Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 35000.0,
#   'launched': '2012-06-09 23:58:18',
#   'pledged': 79937.33,
#   'state': 'successful',
#   'backers': 680.0,
#   'country': 'US',
#   'usd pledged': 79937.33,
#   'usd_pledged_real': 79937.33},
#  {'ID': 1658564725,
#   'name': 'Help Fund a \'Miraculous\'  new Musical, "Miracolo"',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-10-24',
#   'goal': 18000.0,
#   'launched': '2013-09-14 17:41:56',
#   'pledged': 18000.0,
#   'state': 'successful',
#   'backers': 51.0,
#   'country': 'US',
#   'usd pledged': 18000.0,
#   'usd_pledged_real': 18000.0},
#  {'ID': 2071301174,
#   'name': 'Wallets Refined & Redefined - by Obtainium',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-07',
#   'goal': 25000.0,
#   'launched': '2012-11-23 14:59:13',
#   'pledged': 88867.0,
#   'state': 'successful',
#   'backers': 715.0,
#   'country': 'US',
#   'usd pledged': 88867.0,
#   'usd_pledged_real': 88867.0},
#  {'ID': 2055734097,
#   'name': 'Powermitten: EPIC performance and Album Mastering (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-05-04',
#   'goal': 1100.0,
#   'launched': '2011-04-22 08:39:10',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 252240271,
#   'name': 'Best Man Competition Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-03',
#   'goal': 9500.0,
#   'launched': '2013-07-03 20:35:13',
#   'pledged': 377.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd pledged': 377.0,
#   'usd_pledged_real': 377.0},
#  {'ID': 12976470,
#   'name': 'Love Collection',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-02-28',
#   'goal': 5000.0,
#   'launched': '2013-01-29 04:45:19',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 581166953,
#   'name': 'Pay my rent, dance a jig!',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'AUD',
#   'deadline': '2014-08-09',
#   'goal': 3000.0,
#   'launched': '2014-07-10 01:19:48',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'AU',
#   'usd pledged': 0.93876087,
#   'usd_pledged_real': 0.9321401938851605},
#  {'ID': 1780435209,
#   'name': 'The Holophonics Record a New Ska Cover Album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-09-28',
#   'goal': 2000.0,
#   'launched': '2013-08-29 19:07:17',
#   'pledged': 2899.5,
#   'state': 'successful',
#   'backers': 51.0,
#   'country': 'US',
#   'usd pledged': 2899.5,
#   'usd_pledged_real': 2899.5},
#  {'ID': 2057158348,
#   'name': 'BubblePhoneCaseï¿½, Top anti-hacking phone case system.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-12-06',
#   'goal': 10000.0,
#   'launched': '2016-10-31 15:19:14',
#   'pledged': 349.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'ES',
#   'usd pledged': 383.49541128,
#   'usd_pledged_real': 368.5088589952062},
#  {'ID': 93529012,
#   'name': 'Hamtramck Labor Day Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-07-19',
#   'goal': 20000.0,
#   'launched': '2012-06-19 18:04:53',
#   'pledged': 2366.0,
#   'state': 'failed',
#   'backers': 44.0,
#   'country': 'US',
#   'usd pledged': 2366.0,
#   'usd_pledged_real': 2366.0},
#  {'ID': 1551300378,
#   'name': 'Crab Cakes',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-01-01',
#   'goal': 3000.0,
#   'launched': '2012-11-02 18:46:42',
#   'pledged': 775.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 775.0,
#   'usd_pledged_real': 775.0},
#  {'ID': 819881112,
#   'name': 'Excellent "Made in Italy" leather shoes for man/woman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-12-18',
#   'goal': 178250.0,
#   'launched': '2016-11-16 18:18:47',
#   'pledged': 765.0,
#   'state': 'failed',
#   'backers': 19.0,
#   'country': 'IT',
#   'usd pledged': 344.0120416000001,
#   'usd_pledged_real': 799.1225321215919},
#  {'ID': 1776712156,
#   'name': 'Twig the Fairy and the Fairly Short Fairy Tales',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-13',
#   'goal': 17000.0,
#   'launched': '2015-11-21 02:06:15',
#   'pledged': 25410.0,
#   'state': 'successful',
#   'backers': 315.0,
#   'country': 'US',
#   'usd pledged': 25410.0,
#   'usd_pledged_real': 25410.0},
#  {'ID': 255401982,
#   'name': 'Civil Architect',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-12-20',
#   'goal': 100000.0,
#   'launched': '2014-11-20 22:00:13',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 750725377,
#   'name': 'GHETTO CHRONICLES The Musical Comedy Stage Play (Canceled)',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2011-09-04',
#   'goal': 10000.0,
#   'launched': '2011-07-21 08:13:42',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 147428325,
#   'name': 'Flyy Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-02-17',
#   'goal': 10000.0,
#   'launched': '2012-01-18 03:55:27',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'ID': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': '2015-09-29 07:04:08',
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129.0,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'ID': 1050943303,
#   'name': "Little Baby's Ice Cream Funds for Responsible Packaging",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 5952.0,
#   'launched': '2012-06-15 06:03:09',
#   'pledged': 6314.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd pledged': 6314.0,
#   'usd_pledged_real': 6314.0},
#  ...]

# %% [markdown]
# ### Importer les données

# %%
#Si besoin : 
collection.delete_many({})

# %%
collection.insert_many(data_dict)

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'exercices', 'local', 'series']

# %% [markdown]
# ## Question 1
# Récupérer les 5 projets ayant reçu le plus de promesse de dons.

# %%
cur = collection.find().sort([("pledged", -1)]).limit(5)
list(cur)
# Out:
# [{'_id': ObjectId('61dd8dd53bd217711a731f06'),
#   'ID': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-08-30',
#   'goal': 50000.0,
#   'launched': '2014-07-08 10:14:37',
#   'pledged': 13285226.36,
#   'state': 'successful',
#   'backers': 62642.0,
#   'country': 'US',
#   'usd pledged': 13285226.36,
#   'usd_pledged_real': 13285226.36},
#  {'_id': ObjectId('61dd8dd53bd217711a7379ff'),
#   'ID': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-30',
#   'goal': 1000000.0,
#   'launched': '2016-05-24 15:49:52',
#   'pledged': 12779843.49,
#   'state': 'successful',
#   'backers': 66673.0,
#   'country': 'US',
#   'usd pledged': 12779843.49,
#   'usd_pledged_real': 12779843.49},
#  {'_id': ObjectId('61dd8dd53bd217711a732b3d'),
#   'ID': 2111201788,
#   'name': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-11-19',
#   'goal': 800000.0,
#   'launched': '2017-10-10 12:52:25',
#   'pledged': 10035296.0,
#   'state': 'successful',
#   'backers': 6935.0,
#   'country': 'HK',
#   'usd pledged': 4788.64216028,
#   'usd_pledged_real': 1285142.981546224},
#  {'_id': ObjectId('61dd8dd53bd217711a73af1a'),
#   'ID': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-09',
#   'goal': 950000.0,
#   'launched': '2012-07-10 14:44:41',
#   'pledged': 8596474.58,
#   'state': 'successful',
#   'backers': 63416.0,
#   'country': 'US',
#   'usd pledged': 8596474.58,
#   'usd_pledged_real': 8596474.58},
#  {'_id': ObjectId('61dd8dd63bd217711a7426d1'),
#   'ID': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': '2016-07-13 00:47:35',
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359.0,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5}]

# %% [markdown]
# ## Question 2
# Compter le nombre de projets ayant atteint leur but.

# %%
count = collection.count({'state':'successful'})
ratio = count/collection.count()
print("count :",count,"(",ratio*100,"%)")
# Out:
# count : 53040 ( 35.36 %)
# /tmp/ipykernel_15/3333847334.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   count = collection.count({'state':'successful'})
# /tmp/ipykernel_15/3333847334.py:2: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   ratio = count/collection.count()

# %% [markdown]
# ## Question 3
# Compter le nombre de projets pour chaque catégorie.

# %%
cat_count = collection.aggregate([{"$group" : {"_id" : "$category", "count":{"$sum":1}}},{"$sort": {"count":-1}} ])
list(cat_count)
# Out:
# [{'_id': 'Product Design', 'count': 8886},
#  {'_id': 'Documentary', 'count': 6498},
#  {'_id': 'Music', 'count': 6229},
#  {'_id': 'Tabletop Games', 'count': 5581},
#  {'_id': 'Shorts', 'count': 4857},
#  {'_id': 'Video Games', 'count': 4799},
#  {'_id': 'Food', 'count': 4612},
#  {'_id': 'Film & Video', 'count': 4003},
#  {'_id': 'Fiction', 'count': 3703},
#  {'_id': 'Nonfiction', 'count': 3390},
#  {'_id': 'Fashion', 'count': 3379},
#  {'_id': 'Art', 'count': 3358},
#  {'_id': 'Apparel', 'count': 2827},
#  {'_id': 'Theater', 'count': 2786},
#  {'_id': 'Rock', 'count': 2707},
#  {'_id': 'Technology', 'count': 2690},
#  {'_id': "Children's Books", 'count': 2686},
#  {'_id': 'Apps', 'count': 2535},
#  {'_id': 'Publishing', 'count': 2332},
#  {'_id': 'Webseries', 'count': 2316},
#  {'_id': 'Photography', 'count': 2239},
#  {'_id': 'Indie Rock', 'count': 2192},
#  {'_id': 'Narrative Film', 'count': 2099},
#  {'_id': 'Web', 'count': 2017},
#  {'_id': 'Comics', 'count': 1931},
#  {'_id': 'Crafts', 'count': 1834},
#  {'_id': 'Country & Folk', 'count': 1790},
#  {'_id': 'Design', 'count': 1641},
#  {'_id': 'Hip-Hop', 'count': 1555},
#  {'_id': 'Hardware', 'count': 1431},
#  {'_id': 'Games', 'count': 1331},
#  {'_id': 'Pop', 'count': 1302},
#  {'_id': 'Painting', 'count': 1288},
#  {'_id': 'Illustration', 'count': 1263},
#  {'_id': 'Public Art', 'count': 1248},
#  {'_id': 'Gadgets', 'count': 1210},
#  {'_id': 'Accessories', 'count': 1204},
#  {'_id': 'Software', 'count': 1194},
#  {'_id': 'Mixed Media', 'count': 1118},
#  {'_id': 'Restaurants', 'count': 1089},
#  {'_id': 'Art Books', 'count': 1065},
#  {'_id': 'Classical Music', 'count': 1064},
#  {'_id': 'Comic Books', 'count': 1032},
#  {'_id': 'Animation', 'count': 1017},
#  {'_id': 'Drinks', 'count': 995},
#  {'_id': 'Playing Cards', 'count': 963},
#  {'_id': 'Comedy', 'count': 923},
#  {'_id': 'Dance', 'count': 901},
#  {'_id': 'Drama', 'count': 871},
#  {'_id': 'Electronic Music', 'count': 858},
#  {'_id': 'Performance Art', 'count': 855},
#  {'_id': 'World Music', 'count': 850},
#  {'_id': 'Graphic Design', 'count': 765},
#  {'_id': 'Sculpture', 'count': 737},
#  {'_id': 'Jazz', 'count': 733},
#  {'_id': 'Graphic Novels', 'count': 702},
#  {'_id': 'Small Batch', 'count': 701},
#  {'_id': 'Food Trucks', 'count': 687},
#  {'_id': 'Journalism', 'count': 672},
#  {'_id': 'Mobile Games', 'count': 650},
#  {'_id': 'Photobooks', 'count': 608},
#  {'_id': 'Plays', 'count': 539},
#  {'_id': 'Poetry', 'count': 532},
#  {'_id': 'Horror', 'count': 525},
#  {'_id': 'Digital Art', 'count': 524},
#  {'_id': 'Periodicals', 'count': 517},
#  {'_id': 'Wearables', 'count': 508},
#  {'_id': 'Farms', 'count': 482},
#  {'_id': 'DIY', 'count': 480},
#  {'_id': 'Jewelry', 'count': 472},
#  {'_id': 'People', 'count': 440},
#  {'_id': 'Faith', 'count': 439},
#  {'_id': 'Woodworking', 'count': 433},
#  {'_id': 'Performances', 'count': 414},
#  {'_id': 'Television', 'count': 401},
#  {'_id': 'Live Games', 'count': 394},
#  {'_id': 'Conceptual Art', 'count': 393},
#  {'_id': 'Footwear', 'count': 379},
#  {'_id': 'Academic', 'count': 367},
#  {'_id': 'Musical', 'count': 367},
#  {'_id': 'DIY Electronics', 'count': 358},
#  {'_id': 'Experimental', 'count': 357},
#  {'_id': 'Radio & Podcasts', 'count': 349},
#  {'_id': 'Ready-to-wear', 'count': 332},
#  {'_id': 'Spaces', 'count': 331},
#  {'_id': 'Young Adult', 'count': 328},
#  {'_id': 'Events', 'count': 322},
#  {'_id': 'Festivals', 'count': 313},
#  {'_id': 'Thrillers', 'count': 302},
#  {'_id': 'Anthologies', 'count': 300},
#  {'_id': 'Architecture', 'count': 300},
#  {'_id': 'Music Videos', 'count': 299},
#  {'_id': 'Fine Art', 'count': 291},
#  {'_id': 'Print', 'count': 288},
#  {'_id': 'Places', 'count': 283},
#  {'_id': 'Action', 'count': 282},
#  {'_id': 'Metal', 'count': 274},
#  {'_id': 'Science Fiction', 'count': 274},
#  {'_id': '3D Printing', 'count': 271},
#  {'_id': 'Webcomics', 'count': 259},
#  {'_id': 'Sound', 'count': 255},
#  {'_id': 'Robots', 'count': 237},
#  {'_id': 'Vegan', 'count': 229},
#  {'_id': 'Nature', 'count': 219},
#  {'_id': 'Cookbooks', 'count': 217},
#  {'_id': 'Childrenswear', 'count': 192},
#  {'_id': 'Installations', 'count': 178},
#  {'_id': 'Gaming Hardware', 'count': 178},
#  {'_id': "Farmer's Markets", 'count': 175},
#  {'_id': 'R&B', 'count': 172},
#  {'_id': 'Candles', 'count': 168},
#  {'_id': 'Camera Equipment', 'count': 165},
#  {'_id': 'Audio', 'count': 164},
#  {'_id': 'Flight', 'count': 158},
#  {'_id': 'Video', 'count': 147},
#  {'_id': 'Interactive Design', 'count': 146},
#  {'_id': 'Zines', 'count': 144},
#  {'_id': 'Space Exploration', 'count': 137},
#  {'_id': 'Fantasy', 'count': 132},
#  {'_id': 'Immersive', 'count': 131},
#  {'_id': 'Family', 'count': 130},
#  {'_id': 'Civic Design', 'count': 130},
#  {'_id': 'Ceramics', 'count': 128},
#  {'_id': 'Punk', 'count': 127},
#  {'_id': 'Literary Journals', 'count': 118},
#  {'_id': 'Community Gardens', 'count': 115},
#  {'_id': 'Blues', 'count': 113},
#  {'_id': 'Calendars', 'count': 112},
#  {'_id': 'Kids', 'count': 109},
#  {'_id': 'Couture', 'count': 108},
#  {'_id': 'Textiles', 'count': 105},
#  {'_id': 'Animals', 'count': 97},
#  {'_id': 'Fabrication Tools', 'count': 96},
#  {'_id': 'Puzzles', 'count': 95},
#  {'_id': 'Makerspaces', 'count': 91},
#  {'_id': 'Stationery', 'count': 90},
#  {'_id': 'Movie Theaters', 'count': 90},
#  {'_id': 'Printing', 'count': 83},
#  {'_id': 'Knitting', 'count': 78},
#  {'_id': 'Bacon', 'count': 78},
#  {'_id': 'Translations', 'count': 76},
#  {'_id': 'Romance', 'count': 74},
#  {'_id': 'Video Art', 'count': 65},
#  {'_id': 'Latin', 'count': 63},
#  {'_id': 'Crochet', 'count': 61},
#  {'_id': 'Workshops', 'count': 59},
#  {'_id': 'Photo', 'count': 58},
#  {'_id': 'Glass', 'count': 51},
#  {'_id': 'Pet Fashion', 'count': 51},
#  {'_id': 'Embroidery', 'count': 49},
#  {'_id': 'Typography', 'count': 44},
#  {'_id': 'Pottery', 'count': 40},
#  {'_id': 'Weaving', 'count': 38},
#  {'_id': 'Residencies', 'count': 32},
#  {'_id': 'Quilts', 'count': 32},
#  {'_id': 'Letterpress', 'count': 24},
#  {'_id': 'Chiptune', 'count': 10},
#  {'_id': 'Literary Spaces', 'count': 10},
#  {'_id': 'Taxidermy', 'count': 7},
#  {'_id': 'Grace is Leaving', 'count': 1}]

# %% [markdown]
# ## Question 4
# Compter le nombre de projets français ayant été instanciés avant 2016.

# %%
collection.count({"$and":[{"country":"FR"},{ "launched" : { "$lt":"2016-00-00 00:00:00"}}]})
# Out:
# /tmp/ipykernel_15/2447115280.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   collection.count({"$and":[{"country":"FR"},{ "launched" : { "$lt":"2016-00-00 00:00:00"}}]})
# 330

# %% [markdown]
# ## Question 5
# Récupérer les projets américains ayant demandé plus de 200 000 dollars.

# %%
l = collection.find({"$and":[{"country":"US"},{"goal":{"$gt":200000}}]})
print("Nombre : ",l.count())
list(l)
# Out:
# /tmp/ipykernel_15/704656865.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print("Nombre : ",l.count())
# Nombre :  1841
# [{'_id': ObjectId('61dd8dd43bd217711a71f483'),
#   'ID': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 287000.0,
#   'launched': '2012-08-13 23:14:02',
#   'pledged': 1465.0,
#   'state': 'failed',
#   'backers': 11.0,
#   'country': 'US',
#   'usd pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f536'),
#   'ID': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-01',
#   'goal': 250000.0,
#   'launched': '2012-05-01 20:49:58',
#   'pledged': 23680.54,
#   'state': 'failed',
#   'backers': 409.0,
#   'country': 'US',
#   'usd pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': ObjectId('61dd8dd43bd217711a71f53e'),
#   'ID': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-11-04',
#   'goal': 300000.0,
#   'launched': '2013-09-30 18:18:40',
#   'pledged': 12314.0,
#   'state': 'failed',
#   'backers': 50.0,
#   'country': 'US',
#   'usd pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f54d'),
#   'ID': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-09-10',
#   'goal': 3000000.0,
#   'launched': '2017-08-11 18:08:07',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f6d1'),
#   'ID': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-30',
#   'goal': 250000.0,
#   'launched': '2015-05-08 21:03:20',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f6d8'),
#   'ID': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-26',
#   'goal': 250000.0,
#   'launched': '2016-10-27 17:43:14',
#   'pledged': 1996.0,
#   'state': 'failed',
#   'backers': 10.0,
#   'country': 'US',
#   'usd pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f6f7'),
#   'ID': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-31',
#   'goal': 300000.0,
#   'launched': '2016-04-01 22:04:54',
#   'pledged': 11.0,
#   'state': 'suspended',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f715'),
#   'ID': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-08-12',
#   'goal': 1000000.0,
#   'launched': '2016-07-13 17:31:26',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f7da'),
#   'ID': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': '2015-02-10 14:05:34',
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755.0,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f829'),
#   'ID': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-12-15',
#   'goal': 3000000.0,
#   'launched': '2016-11-15 21:06:46',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f85d'),
#   'ID': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-12-12',
#   'goal': 1000000.0,
#   'launched': '2012-11-12 23:27:51',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f884'),
#   'ID': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-11-18',
#   'goal': 250000.0,
#   'launched': '2016-10-19 02:05:16',
#   'pledged': 3085.0,
#   'state': 'failed',
#   'backers': 24.0,
#   'country': 'US',
#   'usd pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f91c'),
#   'ID': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096.0,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f95f'),
#   'ID': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 1000000.0,
#   'launched': '2016-05-18 00:36:35',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f98b'),
#   'ID': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-02-10',
#   'goal': 500000.0,
#   'launched': '2015-01-14 03:01:52',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f98c'),
#   'ID': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-09-30',
#   'goal': 400000.0,
#   'launched': '2014-08-29 20:46:59',
#   'pledged': 9.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f9da'),
#   'ID': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-06',
#   'goal': 466000.0,
#   'launched': '2015-02-10 19:11:52',
#   'pledged': 1076.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f9e5'),
#   'ID': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-07',
#   'goal': 279646.0,
#   'launched': '2014-09-04 18:26:25',
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71f9fe'),
#   'ID': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-04',
#   'goal': 500000.0,
#   'launched': '2017-03-28 19:00:52',
#   'pledged': 22612.0,
#   'state': 'failed',
#   'backers': 36.0,
#   'country': 'US',
#   'usd pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fa43'),
#   'ID': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 1000000.0,
#   'launched': '2015-04-24 02:58:26',
#   'pledged': 171.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71faa8'),
#   'ID': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-15',
#   'goal': 350000.0,
#   'launched': '2013-09-16 22:49:11',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fb0a'),
#   'ID': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-10-14',
#   'goal': 750000.0,
#   'launched': '2017-08-15 19:49:31',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fbe7'),
#   'ID': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 577000.0,
#   'launched': '2014-07-15 00:55:45',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fbf2'),
#   'ID': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 250000.0,
#   'launched': '2016-04-19 06:41:47',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fcec'),
#   'ID': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-26',
#   'goal': 400000.0,
#   'launched': '2016-05-27 17:52:03',
#   'pledged': 146.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fd15'),
#   'ID': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-02-01',
#   'goal': 370000.0,
#   'launched': '2015-12-10 23:55:54',
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fd22'),
#   'ID': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-20',
#   'goal': 300000.0,
#   'launched': '2013-11-20 06:00:07',
#   'pledged': 56667.0,
#   'state': 'failed',
#   'backers': 166.0,
#   'country': 'US',
#   'usd pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fd49'),
#   'ID': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-24',
#   'goal': 545539.0,
#   'launched': '2017-02-22 19:24:24',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fdba'),
#   'ID': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-22',
#   'goal': 100000000.0,
#   'launched': '2015-07-23 21:44:02',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71feb5'),
#   'ID': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-17',
#   'goal': 250000.0,
#   'launched': '2012-12-18 23:01:12',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71fecf'),
#   'ID': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-16',
#   'goal': 3000000.0,
#   'launched': '2015-10-17 00:40:32',
#   'pledged': 101.0,
#   'state': 'canceled',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71ff15'),
#   'ID': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-10-10',
#   'goal': 500000.0,
#   'launched': '2015-09-10 22:58:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71ff95'),
#   'ID': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-21',
#   'goal': 2000000.0,
#   'launched': '2013-05-22 22:02:09',
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('61dd8dd43bd217711a71ffc3'),
#   'ID': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-12-16',
#   'goal': 444000.0,
#   'launched': '2012-11-05 19:05:56',
#   'pledged': 3439.0,
#   'state': 'failed',
#   'backers': 11.0,
#   'country': 'US',
#   'usd pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720002'),
#   'ID': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-23',
#   'goal': 1200000.0,
#   'launched': '2015-06-23 21:12:43',
#   'pledged': 70.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720029'),
#   'ID': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-06',
#   'goal': 400000.0,
#   'launched': '2015-12-08 21:34:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7200fe'),
#   'ID': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-15',
#   'goal': 225000.0,
#   'launched': '2014-03-31 22:46:31',
#   'pledged': 55.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7201bf'),
#   'ID': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-09',
#   'goal': 450000.0,
#   'launched': '2014-10-10 17:48:13',
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7201c5'),
#   'ID': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-31',
#   'goal': 500000.0,
#   'launched': '2014-07-01 04:18:43',
#   'pledged': 272.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7201da'),
#   'ID': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-26',
#   'goal': 270000.0,
#   'launched': '2016-02-26 00:04:18',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7201e2'),
#   'ID': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-08-03',
#   'goal': 300000.0,
#   'launched': '2016-06-04 16:51:18',
#   'pledged': 123.0,
#   'state': 'suspended',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72023f'),
#   'ID': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-22',
#   'goal': 1000000.0,
#   'launched': '2015-11-17 23:36:06',
#   'pledged': 260.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720266'),
#   'ID': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 365000.0,
#   'launched': '2017-04-25 21:25:17',
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720270'),
#   'ID': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-14',
#   'goal': 500000.0,
#   'launched': '2017-11-14 01:35:25',
#   'pledged': 81.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7202a8'),
#   'ID': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-11-30',
#   'goal': 875000.0,
#   'launched': '2017-10-31 06:35:30',
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720310'),
#   'ID': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 250000.0,
#   'launched': '2017-03-11 03:10:44',
#   'pledged': 710.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720356'),
#   'ID': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-14',
#   'goal': 1000000.0,
#   'launched': '2015-01-15 23:33:34',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7203d4'),
#   'ID': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-28',
#   'goal': 500000.0,
#   'launched': '2013-05-29 04:48:42',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72047b'),
#   'ID': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 400000.0,
#   'launched': '2014-06-24 01:26:37',
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7204b9'),
#   'ID': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-03',
#   'goal': 500000.0,
#   'launched': '2015-04-03 01:17:58',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720500'),
#   'ID': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-20',
#   'goal': 250000.0,
#   'launched': '2013-06-20 01:17:50',
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'backers': 45.0,
#   'country': 'US',
#   'usd pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72052a'),
#   'ID': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 400000.0,
#   'launched': '2014-10-24 20:53:50',
#   'pledged': 8.0,
#   'state': 'canceled',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72057c'),
#   'ID': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': '2012-08-15 21:20:10',
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162.0,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('61dd8dd43bd217711a72057e'),
#   'ID': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-26',
#   'goal': 500000.0,
#   'launched': '2014-07-28 09:05:22',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720646'),
#   'ID': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-19',
#   'goal': 1000000.0,
#   'launched': '2015-10-20 00:56:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720672'),
#   'ID': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-10-31',
#   'goal': 1000000.0,
#   'launched': '2016-10-01 19:42:33',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720754'),
#   'ID': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-24',
#   'goal': 250000.0,
#   'launched': '2013-09-25 18:39:09',
#   'pledged': 2110.0,
#   'state': 'failed',
#   'backers': 18.0,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720764'),
#   'ID': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-02',
#   'goal': 313550.0,
#   'launched': '2013-10-18 09:18:13',
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7207c6'),
#   'ID': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-15',
#   'goal': 2000000.0,
#   'launched': '2016-07-20 18:37:09',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720816'),
#   'ID': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-06-17',
#   'goal': 1000000.0,
#   'launched': '2012-05-18 08:18:34',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72091a'),
#   'ID': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 2000000.0,
#   'launched': '2016-06-03 23:59:11',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72093c'),
#   'ID': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-09-20',
#   'goal': 210000.0,
#   'launched': '2011-08-02 15:54:48',
#   'pledged': 12058.3,
#   'state': 'failed',
#   'backers': 117.0,
#   'country': 'US',
#   'usd pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': ObjectId('61dd8dd43bd217711a720948'),
#   'ID': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 8000000.0,
#   'launched': '2016-04-06 20:30:05',
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720998'),
#   'ID': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-11',
#   'goal': 900000.0,
#   'launched': '2013-11-11 10:41:59',
#   'pledged': 47939.0,
#   'state': 'failed',
#   'backers': 1362.0,
#   'country': 'US',
#   'usd pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7209cf'),
#   'ID': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-08-20',
#   'goal': 350000.0,
#   'launched': '2016-07-21 03:42:14',
#   'pledged': 2508.0,
#   'state': 'failed',
#   'backers': 26.0,
#   'country': 'US',
#   'usd pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7209f8'),
#   'ID': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-03-19',
#   'goal': 275000.0,
#   'launched': '2015-02-17 19:40:55',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720a1b'),
#   'ID': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-05',
#   'goal': 350000.0,
#   'launched': '2016-09-21 20:21:50',
#   'pledged': 1865.0,
#   'state': 'failed',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720a83'),
#   'ID': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': '2014-07-15 08:19:05',
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657.0,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720af2'),
#   'ID': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-15',
#   'goal': 2000000.0,
#   'launched': '2014-05-01 20:01:10',
#   'pledged': 225.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720afc'),
#   'ID': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-12-31',
#   'goal': 250000.0,
#   'launched': '2015-11-19 16:47:03',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720b1a'),
#   'ID': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-13',
#   'goal': 1000000.0,
#   'launched': '2015-08-14 22:56:40',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720b44'),
#   'ID': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-10-04',
#   'goal': 500000.0,
#   'launched': '2015-08-06 22:22:00',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720b9c'),
#   'ID': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-24',
#   'goal': 1100000.0,
#   'launched': '2016-01-26 05:48:05',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720da1'),
#   'ID': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 700000.0,
#   'launched': '2017-04-01 02:34:51',
#   'pledged': 56.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720dff'),
#   'ID': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-18',
#   'goal': 2300000.0,
#   'launched': '2012-07-19 21:12:51',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720e66'),
#   'ID': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-08-27',
#   'goal': 250000.0,
#   'launched': '2014-06-28 22:05:03',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720e6e'),
#   'ID': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-04-19',
#   'goal': 780000.0,
#   'launched': '2015-02-18 17:23:50',
#   'pledged': 267.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720e7c'),
#   'ID': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-06-18',
#   'goal': 750000.0,
#   'launched': '2014-05-19 03:56:46',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720e7f'),
#   'ID': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2018-01-11',
#   'goal': 500000.0,
#   'launched': '2017-12-12 18:46:26',
#   'pledged': 5651.0,
#   'state': 'live',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720e9e'),
#   'ID': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-31',
#   'goal': 900000.0,
#   'launched': '2014-12-01 23:50:57',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720eb2'),
#   'ID': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 1040000.0,
#   'launched': '2014-06-24 02:58:50',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720eb8'),
#   'ID': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 1000000.0,
#   'launched': '2017-03-03 21:30:39',
#   'pledged': 1.0,
#   'state': 'suspended',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720eec'),
#   'ID': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-23',
#   'goal': 250000.0,
#   'launched': '2016-06-23 01:13:20',
#   'pledged': 10100.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720f45'),
#   'ID': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-02-17',
#   'goal': 1200000.0,
#   'launched': '2014-01-13 19:08:09',
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720fc3'),
#   'ID': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-07-27',
#   'goal': 250000.0,
#   'launched': '2014-05-28 19:42:35',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('61dd8dd43bd217711a720fde'),
#   'ID': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-03-16',
#   'goal': 300000.0,
#   'launched': '2013-02-09 21:01:57',
#   'pledged': 27581.0,
#   'state': 'failed',
#   'backers': 116.0,
#   'country': 'US',
#   'usd pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7210aa'),
#   'ID': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-09-16',
#   'goal': 250000.0,
#   'launched': '2013-08-16 04:59:36',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7210c3'),
#   'ID': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': '2014-01-14 19:03:30',
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824.0,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('61dd8dd43bd217711a721170'),
#   'ID': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-03',
#   'goal': 1800000.0,
#   'launched': '2016-01-04 20:26:57',
#   'pledged': 614.0,
#   'state': 'failed',
#   'backers': 14.0,
#   'country': 'US',
#   'usd pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72117a'),
#   'ID': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-17',
#   'goal': 1500000.0,
#   'launched': '2013-07-12 02:38:19',
#   'pledged': 275.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721199'),
#   'ID': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-11',
#   'goal': 250000.0,
#   'launched': '2014-07-17 15:54:12',
#   'pledged': 3536.0,
#   'state': 'failed',
#   'backers': 39.0,
#   'country': 'US',
#   'usd pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721210'),
#   'ID': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-10-27',
#   'goal': 40000000.0,
#   'launched': '2015-09-27 15:08:05',
#   'pledged': 21700.0,
#   'state': 'failed',
#   'backers': 15.0,
#   'country': 'US',
#   'usd pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721256'),
#   'ID': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-07-12',
#   'goal': 500000.0,
#   'launched': '2015-05-13 03:45:32',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721266'),
#   'ID': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-28',
#   'goal': 340000.0,
#   'launched': '2015-10-29 16:00:52',
#   'pledged': 19328.0,
#   'state': 'failed',
#   'backers': 273.0,
#   'country': 'US',
#   'usd pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7212d5'),
#   'ID': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-23',
#   'goal': 250000.0,
#   'launched': '2017-05-24 00:17:26',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7212f4'),
#   'ID': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-01',
#   'goal': 300000.0,
#   'launched': '2014-06-02 15:53:58',
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721331'),
#   'ID': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-09',
#   'goal': 375000.0,
#   'launched': '2017-09-12 21:06:34',
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721384'),
#   'ID': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 500000.0,
#   'launched': '2013-05-08 18:00:16',
#   'pledged': 70.0,
#   'state': 'canceled',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721427'),
#   'ID': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': '2014-11-19 20:20:55',
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7214b8'),
#   'ID': 381953552,
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-08',
#   'goal': 350000.0,
#   'launched': '2014-09-03 01:33:36',
#   'pledged': 60.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721612'),
#   'ID': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239.0,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72165b'),
#   'ID': 1812682282,
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-12-31',
#   'goal': 2500000.0,
#   'launched': '2011-12-05 17:22:45',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7216fc'),
#   'ID': 892520897,
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-02',
#   'goal': 10000000.0,
#   'launched': '2013-05-03 23:15:16',
#   'pledged': 11975.0,
#   'state': 'failed',
#   'backers': 24.0,
#   'country': 'US',
#   'usd pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72172b'),
#   'ID': 396599619,
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-01',
#   'goal': 380000.0,
#   'launched': '2015-08-17 09:43:37',
#   'pledged': 950.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd pledged': 950.0,
#   'usd_pledged_real': 950.0},
#  {'_id': ObjectId('61dd8dd43bd217711a72176d'),
#   'ID': 2028395602,
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 300000.0,
#   'launched': '2013-03-27 04:05:39',
#   'pledged': 27614.0,
#   'state': 'failed',
#   'backers': 161.0,
#   'country': 'US',
#   'usd pledged': 27614.0,
#   'usd_pledged_real': 27614.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7217b7'),
#   'ID': 233857280,
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-04-29',
#   'goal': 2000000.0,
#   'launched': '2017-03-30 05:36:14',
#   'pledged': 192.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 192.0},
#  {'_id': ObjectId('61dd8dd43bd217711a7217c2'),
#   'ID': 1489384109,
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-15',
#   'goal': 300000.0,
#   'launched': '2017-08-16 15:47:26',
#   'pledged': 48307.0,
#   'state': 'canceled',
#   'backers': 325.0,
#   'country': 'US',
#   'usd pledged': 9302.0,
#   'usd_pledged_real': 48307.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721916'),
#   'ID': 515152452,
#   'name': 'Love Gives Hope Art Gallery for Cultural Diversity!',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2017-09-12',
#   'goal': 300000.0,
#   'launched': '2017-08-13 23:22:40',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721936'),
#   'ID': 549303222,
#   'name': 'The "Get Home Now" Device',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-14',
#   'goal': 250000.0,
#   'launched': '2014-09-30 19:45:59',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721a00'),
#   'ID': 599813105,
#   'name': 'In Pursuit of Passion - Travel Television Series',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-06-06',
#   'goal': 280000.0,
#   'launched': '2016-05-07 00:56:56',
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721a2e'),
#   'ID': 1327325648,
#   'name': 'Welcome to the Wonderful World of AIDS',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-11-26',
#   'goal': 500000.0,
#   'launched': '2014-10-27 04:27:59',
#   'pledged': 2827.0,
#   'state': 'failed',
#   'backers': 24.0,
#   'country': 'US',
#   'usd pledged': 2827.0,
#   'usd_pledged_real': 2827.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721a4b'),
#   'ID': 35012487,
#   'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-21',
#   'goal': 500000.0,
#   'launched': '2016-01-21 23:34:11',
#   'pledged': 116.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 116.0,
#   'usd_pledged_real': 116.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721a89'),
#   'ID': 1109856918,
#   'name': 'From Dawson to Jackson Vineyards',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-02',
#   'goal': 1000000.0,
#   'launched': '2014-09-02 23:28:18',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721c30'),
#   'ID': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': '2013-07-07 23:34:52',
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785.0,
#   'country': 'US',
#   'usd pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721c6f'),
#   'ID': 918134505,
#   'name': 'My a MAZING Academic Profile',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 2852666.0,
#   'launched': '2014-07-21 22:13:47',
#   'pledged': 130.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 130.0,
#   'usd_pledged_real': 130.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721c91'),
#   'ID': 1254826758,
#   'name': 'The Hill (Canceled)',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2014-11-12',
#   'goal': 1575000.0,
#   'launched': '2014-09-22 22:23:33',
#   'pledged': 203.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'_id': ObjectId('61dd8dd43bd217711a721ca2'),
#   'ID': 12584764,
# ...
#   'usd_pledged_real': 2500.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732875'),
#   'ID': 2091396529,
#   'name': 'Bistraung Brewing Company',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-11-11',
#   'goal': 2400000.0,
#   'launched': '2015-10-12 23:58:26',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73288f'),
#   'ID': 511118298,
#   'name': 'MelloShip',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-10-22',
#   'goal': 350000.0,
#   'launched': '2016-09-19 21:08:37',
#   'pledged': 1492.0,
#   'state': 'failed',
#   'backers': 21.0,
#   'country': 'US',
#   'usd pledged': 310.0,
#   'usd_pledged_real': 1492.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7328da'),
#   'ID': 1252853381,
#   'name': 'Muv-Luv: A Pretty Sweet Visual Novel Series',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-03',
#   'goal': 250000.0,
#   'launched': '2015-09-24 20:54:25',
#   'pledged': 1255444.0,
#   'state': 'successful',
#   'backers': 7890.0,
#   'country': 'US',
#   'usd pledged': 1255444.0,
#   'usd_pledged_real': 1255444.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732a28'),
#   'ID': 1593659820,
#   'name': 'MINED IN DETROIT! BBQ/BROIL NaCl (Salt) Block. THE D@ 801ï¿½C.',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-01-01',
#   'goal': 777777.0,
#   'launched': '2015-11-25 00:43:55',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732a43'),
#   'ID': 2120153871,
#   'name': 'Kasimono (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-11-17',
#   'goal': 550000.0,
#   'launched': '2012-10-17 20:23:23',
#   'pledged': 20793.0,
#   'state': 'canceled',
#   'backers': 34.0,
#   'country': 'US',
#   'usd pledged': 20793.0,
#   'usd_pledged_real': 20793.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732b1f'),
#   'ID': 184465225,
#   'name': 'EL extraterrestrial life',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-05-30',
#   'goal': 500000.0,
#   'launched': '2015-03-31 01:39:55',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732b37'),
#   'ID': 666676350,
#   'name': '223 Brush Street',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2016-04-18',
#   'goal': 5000000.0,
#   'launched': '2016-03-24 17:34:35',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732bab'),
#   'ID': 1240992350,
#   'name': 'The refuge.',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-25',
#   'goal': 350000.0,
#   'launched': '2015-09-25 16:33:50',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732c24'),
#   'ID': 783490068,
#   'name': '"RESTORING FREEDOM"',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2016-01-02',
#   'goal': 1500000.0,
#   'launched': '2015-12-03 00:05:28',
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732c46'),
#   'ID': 1086775799,
#   'name': 'Rise Of The Martians - Destroy All Humans',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-11-05',
#   'goal': 500000.0,
#   'launched': '2014-10-06 21:33:58',
#   'pledged': 51.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 51.0,
#   'usd_pledged_real': 51.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732c50'),
#   'ID': 1859575272,
#   'name': 'Multifamily Apartment development',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2016-08-20',
#   'goal': 1200000.0,
#   'launched': '2016-07-20 03:08:05',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732ca0'),
#   'ID': 1356175125,
#   'name': 'Power Knot Save the planet, NO food waste to the landfill',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-13',
#   'goal': 250000.0,
#   'launched': '2015-03-14 02:11:38',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732e22'),
#   'ID': 1413335650,
#   'name': 'Fish Bonez...Fresh Seafood Grill',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-11-16',
#   'goal': 250000.0,
#   'launched': '2012-09-17 21:33:22',
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 125.0,
#   'usd_pledged_real': 125.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732e99'),
#   'ID': 172516885,
#   'name': 'The Ultimate Sacrifice: Depicted in Sculptural Glass & Light',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-04-26',
#   'goal': 850000.0,
#   'launched': '2015-03-17 16:25:08',
#   'pledged': 1257.0,
#   'state': 'canceled',
#   'backers': 9.0,
#   'country': 'US',
#   'usd pledged': 1257.0,
#   'usd_pledged_real': 1257.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732f09'),
#   'ID': 1586943977,
#   'name': 'The Directorate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-10-05',
#   'goal': 235000.0,
#   'launched': '2012-09-05 23:36:39',
#   'pledged': 11285.27,
#   'state': 'failed',
#   'backers': 400.0,
#   'country': 'US',
#   'usd pledged': 11285.27,
#   'usd_pledged_real': 11285.27},
#  {'_id': ObjectId('61dd8dd53bd217711a732f20'),
#   'ID': 1861707770,
#   'name': 'Believers',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-10-22',
#   'goal': 10000000.0,
#   'launched': '2013-08-23 16:57:54',
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732f6c'),
#   'ID': 617735693,
#   'name': 'SOAK: An Ecological Urban Bathhouse',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-01-01',
#   'goal': 240000.0,
#   'launched': '2013-11-26 06:25:19',
#   'pledged': 26508.0,
#   'state': 'failed',
#   'backers': 167.0,
#   'country': 'US',
#   'usd pledged': 26508.0,
#   'usd_pledged_real': 26508.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732f6e'),
#   'ID': 1401115858,
#   'name': '"THAT WHICH LURKS" a Japanese horror graphic novel.',
#   'category': 'Graphic Novels',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2017-03-08',
#   'goal': 800000.0,
#   'launched': '2017-01-11 22:35:10',
#   'pledged': 820.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd pledged': 45.0,
#   'usd_pledged_real': 820.0},
#  {'_id': ObjectId('61dd8dd53bd217711a732fa1'),
#   'ID': 607788518,
#   'name': 'Night of the Demons: After-Party',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-17',
#   'goal': 225000.0,
#   'launched': '2013-06-17 17:06:48',
#   'pledged': 5612.66,
#   'state': 'failed',
#   'backers': 61.0,
#   'country': 'US',
#   'usd pledged': 5612.66,
#   'usd_pledged_real': 5612.66},
#  {'_id': ObjectId('61dd8dd53bd217711a73309d'),
#   'ID': 611155791,
#   'name': 'Deadlands III: The New World (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-26',
#   'goal': 1000000.0,
#   'launched': '2010-07-28 21:54:36',
#   'pledged': 4462.0,
#   'state': 'canceled',
#   'backers': 21.0,
#   'country': 'US',
#   'usd pledged': 4462.0,
#   'usd_pledged_real': 4462.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7330d0'),
#   'ID': 235391610,
#   'name': 'ANNIHILATOR is a NO holds bar super car built 4 21st century',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-28',
#   'goal': 1000000.0,
#   'launched': '2015-03-26 08:30:58',
#   'pledged': 1085.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 1085.0,
#   'usd_pledged_real': 1085.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7330d2'),
#   'ID': 777796215,
#   'name': "JP's Fully Automated Burger Machine",
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-12',
#   'goal': 350000.0,
#   'launched': '2016-09-28 22:58:32',
#   'pledged': 181.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd pledged': 360.0,
#   'usd_pledged_real': 181.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7330f8'),
#   'ID': 2133507572,
#   'name': 'Unfinished Furniture',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-05-25',
#   'goal': 300000.0,
#   'launched': '2013-04-25 22:44:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73310b'),
#   'ID': 28326293,
#   'name': 'Untitled Taraji P. Henson and Michael Ealy',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-08-17',
#   'goal': 300000.0,
#   'launched': '2017-07-18 03:50:29',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7331e3'),
#   'ID': 439416501,
#   'name': 'ANTIDOTE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-17',
#   'goal': 300000.0,
#   'launched': '2012-06-18 21:16:42',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73323c'),
#   'ID': 493623060,
#   'name': 'Legend Of The Keepers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-12',
#   'goal': 450000.0,
#   'launched': '2015-12-14 15:53:06',
#   'pledged': 14.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 14.0,
#   'usd_pledged_real': 14.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73324e'),
#   'ID': 1845730356,
#   'name': 'Agora (Canceled)',
#   'category': 'Spaces',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-10',
#   'goal': 300000.0,
#   'launched': '2016-01-11 19:33:54',
#   'pledged': 7200.0,
#   'state': 'canceled',
#   'backers': 5.0,
#   'country': 'US',
#   'usd pledged': 7200.0,
#   'usd_pledged_real': 7200.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73328b'),
#   'ID': 1377112614,
#   'name': 'Just Fellowship',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-01-21',
#   'goal': 250000.0,
#   'launched': '2014-11-22 16:49:36',
#   'pledged': 80.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('61dd8dd53bd217711a733294'),
#   'ID': 1407711307,
#   'name': 'An Everyday Gift To Our Veterans.',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-05',
#   'goal': 430000.0,
#   'launched': '2016-03-18 15:08:05',
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7332bf'),
#   'ID': 1055272393,
#   'name': 'Rover Blowerï¿½ (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-24',
#   'goal': 250000.0,
#   'launched': '2014-04-19 16:39:16',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73331e'),
#   'ID': 1476292196,
#   'name': 'Infameous',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-31',
#   'goal': 259000.0,
#   'launched': '2013-07-03 18:13:36',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73336f'),
#   'ID': 1351667354,
#   'name': 'Orderfoood Technologies',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-07',
#   'goal': 1000000.0,
#   'launched': '2017-08-08 23:54:15',
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('61dd8dd53bd217711a73337c'),
#   'ID': 1979330873,
#   'name': 'Axis Game Factory - dream, build, create and play!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-05',
#   'goal': 400000.0,
#   'launched': '2013-01-02 18:09:12',
#   'pledged': 25209.0,
#   'state': 'failed',
#   'backers': 263.0,
#   'country': 'US',
#   'usd pledged': 25209.0,
#   'usd_pledged_real': 25209.0},
#  {'_id': ObjectId('61dd8dd53bd217711a733459'),
#   'ID': 1602722212,
#   'name': 'Mount Grace Monastery Replica',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-05-12',
#   'goal': 16250000.0,
#   'launched': '2015-03-13 16:57:27',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7334bb'),
#   'ID': 723636757,
#   'name': 'World Domination: Gamers cafe and Lounge',
#   'category': 'Spaces',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-05-10',
#   'goal': 500000.0,
#   'launched': '2015-03-11 20:09:20',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a733560'),
#   'ID': 626473194,
#   'name': 'Festival of Magic - Wii U/PC/Mac/Linux/Steam (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-22',
#   'goal': 250000.0,
#   'launched': '2013-11-21 00:18:19',
#   'pledged': 49286.55,
#   'state': 'canceled',
#   'backers': 1417.0,
#   'country': 'US',
#   'usd pledged': 49286.55,
#   'usd_pledged_real': 49286.55},
#  {'_id': ObjectId('61dd8dd53bd217711a7335a4'),
#   'ID': 2123518228,
#   'name': 'On Demand Delivery and Transportation Services!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-15',
#   'goal': 500000.0,
#   'launched': '2015-01-16 23:36:34',
#   'pledged': 226.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd pledged': 226.0,
#   'usd_pledged_real': 226.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7335ca'),
#   'ID': 5190029,
#   'name': "The Patrick Kyle Children's Museum",
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-08-25',
#   'goal': 2000000.0,
#   'launched': '2015-06-26 20:16:29',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('61dd8dd53bd217711a7335f9'),
#   'ID': 1891106526,
#   'name': 'Class of Heroes 2 Deluxe for the PSPï¿½ system',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-04-27',
#   'goal': 500000.0,
#   'launched': '2012-03-28 08:59:58',
#   'pledged': 96951.01,
#   'state': 'failed',
#   'backers': 882.0,
#   'country': 'US',
#   'usd pledged': 96951.01,
#   'usd_pledged_real': 96951.01},
#  ...]

# %% [markdown]
# ## Question 6
# Compter le nombre de projet ayant "Sport" dans leur nom

# %%
collection.create_index([("name",  "text")])
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'name_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('name', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %%
collection.count({"$text":{"$search":"Sport"}})
# Out:
# /tmp/ipykernel_15/2766307636.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   collection.count({"$text":{"$search":"Sport"}})
# 318
